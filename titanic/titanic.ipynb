# %%
import pandas as pd
import numpy as np

# 学習データ、テストデータの読み込み
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# 学習データを特徴量と目的変数に分ける
train_x = train.drop(['Survived'], axis=1)
train_y = train['Survived']

# テストデータは特徴量のみなので、そのままでよい
test_x = test.copy() # copyメソッドでtestデータをコピーすることで"深いコピー"を行える

# --浅いコピーと深いコピー--
# 浅いコピー：コピー元のオブジェクトの参照をコピーする
# - 参照をコピーするので、コピー元のオブジェクトを変更するとコピー先のオブジェクトも変更される
# 深いコピー：コピー元のオブジェクトの値をコピーする
# - 値をコピーするので、コピー元のオブジェクトを変更してもコピー先のオブジェクトは変更されない
